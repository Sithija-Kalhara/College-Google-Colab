# %% [markdown]
# <a href="https://colab.research.google.com/github/Sithija-Kalhara/College-Google-Colab/blob/main/Untitled6202607023rd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data ={
    "student_ID":[101,102,103],
    "Name":["john","Emma","David"],
    "Age":[20,21,22],
    "City":["Tokyo","Osaka","Kyoto"]
}
df = pd.DataFrame(data)
print(df)
