# %% [markdown]
# <a href="https://colab.research.google.com/github/Sithija-Kalhara/College-Google-Colab/blob/main/read%20exel%20sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_name = "Pandas_Practice_Datasets_20_Sheets.xlsx"

# %%
df = pd.read_excel(file_name, sheet_name='Students')
print(df)
# Out:
#    Student_ID      Name  Age  Gender     Department  Year     City  Marks  \
# 0       ST102   Sample1   20    Male   Department_1    15   City_1     15
# 1       ST103   Sample2   21  Female   Department_2    22   City_2     22
# 2       ST104   Sample3   22    Male   Department_3    29   City_3     29
# 3       ST105   Sample4   23  Female   Department_4    36   City_4     36
# 4       ST106   Sample5   24    Male   Department_5    43   City_5     43
# 5       ST107   Sample6   25  Female   Department_6    50   City_6     50
# 6       ST108   Sample7   26    Male   Department_7    57   City_7     57
# 7       ST109   Sample8   27  Female   Department_8    64   City_8     64
# 8       ST110   Sample9   18    Male   Department_9    71   City_9     71
# 9       ST111  Sample10   19  Female  Department_10    78  City_10     78
# 10      ST112  Sample11   20    Male  Department_11    85  City_11     85
# 11      ST113  Sample12   21  Female  Department_12    92  City_12     92
# ...
